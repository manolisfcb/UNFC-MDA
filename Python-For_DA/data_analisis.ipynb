# %%
import pandas as pd

# %%
DATA = pd.read_excel('sample_data - Copy.xlsx')

# %%
DATA
# Out:
#    User ID  Before Gamification (minutes)  After Gamification (minutes)
# 0   User 1                             12                            18
# 1   User 2                             10                            15
# 2   User 3                             14                            20
# 3   User 4                             11                            16
# 4   User 5                             13                            19
# 5   User 6                             10                            17
# 6   User 7                             12                            18
# 7   User 8                             11                            15
# 8   User 9                             13                            20
# 9  User 10                             12                            19

# %%
import numpy as np
data = np.array([3, 7, 4, 9, 10, 6, 12, 9, 2])

# %%
mean = np.mean(data)
mean
# Out:
# np.float64(6.888888888888889)

# %%
median = np.median(data)
median
# Out:
# np.float64(7.0)

# %%
# The code snippet is adding the value 5 to an existing array or list called `data`, then calculating the mean of the updated data array. The `np.append()` function is used to add the value 5 to the existing data array, and then `np.mean()` is used to calculate the mean of the updated data array.
# # if add a 5 to the data
# data = np.append(data, 5)
# mean = np.mean(data)
# mean

# %%
median = np.median(data)
median
# Out:
# np.float64(7.0)

# %%
from scipy import stats
mode = stats.mode(data)
mode
# Out:
# ModeResult(mode=np.int64(9), count=np.int64(2))

# %%
range_ = np.ptp(data)
range_
# Out:
# np.int64(10)

# %%
# Quatiles
q1 = np.percentile(data, 25)
q1
# Mediana 25% - 50% - 75%
# Out:
# np.float64(4.0)

# %%
q2 = np.percentile(data, 50)
q2
# Out:
# np.float64(7.0)

# %%
q3 = np.percentile(data, 75)
q3
# Out:
# np.float64(9.0)

# %%
IQR = q3 - q1
IQR
# Out:
# np.float64(5.0)

# %%
datadf = pd.DataFrame(data, columns=['data'])
datadf
# Out:
#    data
# 0     3
# 1     7
# 2     4
# 3     9
# 4    10
# 5     6
# 6    12
# 7     9
# 8     2

# %%
datadf.describe()
# Out:
#             data
# count   9.000000
# mean    6.888889
# std     3.407508
# min     2.000000
# 25%     4.000000
# 50%     7.000000
# 75%     9.000000
# max    12.000000

# %%
q1 = np.mean(data[:int(len(data)//2)-1])
q1
# Out:
# np.float64(4.666666666666667)

# %%
np.mean(data[:int(len(data)//2)])
# Out:
# np.float64(5.75)

# %%
5.65/33.45
# Out:
# 0.16890881913303438

# %%
from matplotlib import pyplot as plt
fig = plt.boxplot(data)
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
